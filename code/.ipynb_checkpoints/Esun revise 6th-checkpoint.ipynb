# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # EDA

# %%
#當前工作路徑
import os
#os.chdir("C:\\Users\\yunting\\Documents\\GitHub\\E.sun_conpetition")   #修改当前工作目录
#os.getcwd()    #找當前工作路徑

# %%
train  = pd.read_csv('../../E.sun_conpetition/data_set/train.csv')
test = pd.read_csv('../../E.sun_conpetition/data_set/train.csv')

# %% [markdown]
# 看y的分布

# %%
y = train['total_price']

# %%
sorted_y = np.sort(y)

# %%
plt.step(np.arange(sorted_y.size), sorted_y)

# %%
logy = np.log2(y)

# %%
sorted_logy = np.sort(logy)

# %%
plt.plot(sorted_logy)

# %% [markdown]
# corr

# %%
import seaborn as sns

# %%
log_unit_y = train['log_unit_price']

# %%
train['unit_price'] = train['total_price']/train['building_area']
train['log_unit_price'] = np.log2(train['unit_price'])
train['log_total_price'] = np.log2(train['total_price'])
train['log_building_area'] = np.log2(train['building_area'])
train.head()
# Out:
#         building_id  building_material  city  txn_dt  total_floor  \
# 0  e3mMIMR3JJqCaXz1                  8    21   18674            4
# 1  LgwzgklNvy4QCtq5                  8     7   18800            5
# 2  ucIR2NLLsC3T650L                  8     7   19289            4
# 3  jre1pJhcQj91Kdky                  8    21   20385           24
# 4  rQpYpY9nRG7X5mmr                  1    21   20657            2
#
#    building_type  building_use  building_complete_dt  parking_way  \
# 0              3             2                  6271            2
# 1              1             2                  7885            2
# 2              1             2                  6028            2
# 3              0             2                 18325            0
# 4              4             2                  6880            2
#
#    parking_area  ...  XIV_index_5000  XIV_10000  XIV_index_10000     XIV_MIN  \
# 0           NaN  ...               1       6011                1   34.469803
# ...

# %%
train_front = train.iloc[:, :32]

# %%
train_corr = pd.concat([train_front, train['log_total_price'], train['log_unit_price']], axis =1)

# %%
corrmat = train_corr.corr()
f, ax = plt.subplots(figsize=(30, 20))
sns.heatmap(corrmat, vmin=0, vmax=1, square=True, annot=True)

# %%
#sns.distplot(train['city'], kde=False)
sns.countplot(train['city']) #分類直方圖
# KH(21), NTC(7), TC(12), TP(13), TN(14), guess:TY(10) 6直轄市

# %%
city_5 = train.loc[train['city'].isin(['21', '7', '12', '13', '14'])]
city_5.head()
# Out:
#         building_id  building_material  city  txn_dt  total_floor  \
# 0  e3mMIMR3JJqCaXz1                  8    21   18674            4
# 1  LgwzgklNvy4QCtq5                  8     7   18800            5
# 2  ucIR2NLLsC3T650L                  8     7   19289            4
# 3  jre1pJhcQj91Kdky                  8    21   20385           24
# 4  rQpYpY9nRG7X5mmr                  1    21   20657            2
#
#    building_type  building_use  building_complete_dt  parking_way  \
# 0              3             2                  6271            2
# 1              1             2                  7885            2
# 2              1             2                  6028            2
# 3              0             2                 18325            0
# 4              4             2                  6880            2
#
#    parking_area  ...  XIV_index_5000  XIV_10000  XIV_index_10000     XIV_MIN  \
# 0           NaN  ...               1       6011                1   34.469803
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='city', y='total_floor', hue='building_type',data=city_5, palette="Set3")

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(x='lon', y='lat', hue='city', data=train)

# %%
cc_agg1 = train[['city', 'log_unit_price']].groupby('city').agg(['max', 'median', 'mean', 'min'])
cc_agg1.columns = ['city_max_price', 'city_med_price', 'city_mean_price', 'city_min_price']
cc_agg1.head()
# Out:
#       city_max_price  city_med_price  city_mean_price  city_min_price
# city
# 3          20.314241       18.102440        18.155378       16.040382
# 5          22.008992       17.383005        17.437543       14.479556
# 6          25.457656       18.153300        18.260504       14.855183
# 7          25.229785       20.082000        20.027957       15.655093
# 9          23.945486       18.849582        18.759366       14.800555

# %%
cc_agg3 = train[['town', 'log_unit_price']].groupby('town').agg(['max', 'median', 'mean', 'min'])
cc_agg3.columns = ['town_max_price', 'town_med_price', 'town_mean_price', 'town_min_price']
cc_agg3.head()
# Out:
#       town_max_price  town_med_price  town_mean_price  town_min_price
# town
# 0          19.912528       18.511728        18.492872       17.247305
# 4          20.964607       19.249592        19.184373       16.617704
# 6          23.919155       18.254082        18.391637       16.367781
# 7          18.454188       17.439130        17.282794       16.312948
# 8          19.013915       17.887436        18.057223       16.964486

# %%
from catboost import CatBoostRegressor ,Pool

# %%
a = train['log_building_area']

# %%
train
# Out:
#             building_id  building_material  city  txn_dt  total_floor  \
# 0      e3mMIMR3JJqCaXz1                  8    21   18674            4
# 1      LgwzgklNvy4QCtq5                  8     7   18800            5
# 2      ucIR2NLLsC3T650L                  8     7   19289            4
# 3      jre1pJhcQj91Kdky                  8    21   20385           24
# 4      rQpYpY9nRG7X5mmr                  1    21   20657            2
# 5      HmW2MkrwafmceWAH                  8    21   18394            5
# 6      ITYyim3zx6DQyCoF                  8     7   20474           15
# 7      KFrxqaWZaLynrOae                  8    12   18185            8
# 8      ZiK0gY7A0BvwZ8OV                  8    21   18794            5
# 9      QnytA7FbgaVxIDuP                  8     7   19927           10
# 10     jcbuA8q3KPH9SzpS                  1     7   18333            2
# 11     KHo10f3pvTcVL7Dc                  8    21   18184            5
# ...

# %%
X2 = train.iloc[:,1:-6]

# %%
X2 = pd.concat([X2,a],axis=1)

# %%
X2 = X2.fillna(0)

# %%
X2.shape
# Out:
# (60000, 234)

# %%
X = train_front.iloc[:,1:]

# %%
X  = X.fillna(0)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 31 columns):
# building_material          60000 non-null int64
# city                       60000 non-null int64
# txn_dt                     60000 non-null int64
# total_floor                60000 non-null int64
# building_type              60000 non-null int64
# building_use               60000 non-null int64
# building_complete_dt       60000 non-null int64
# parking_way                60000 non-null int64
# parking_area               60000 non-null float64
# parking_price              60000 non-null float64
# txn_floor                  60000 non-null float64
# land_area                  60000 non-null float64
# building_area              60000 non-null float64
# town                       60000 non-null int64
# lat                        60000 non-null float64
# lon                        60000 non-null float64
# village_income_median      60000 non-null float64
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_validation, y_train, y_validation = train_test_split(X3,log_unit_y , train_size=0.7, random_state=1234)

# %%
model=CatBoostRegressor(iterations=100, depth=8,l2_leaf_reg=0.01, learning_rate=0.1)
A = model.fit(X_train, y_train,eval_set=(X_validation, y_validation),plot=True)
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
# ...

# %%
from sklearn.model_selection import cross_val_score

# %%
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# %%
model2 = LGBMRegressor(n_estimators=200,learning_rate=0.1,num_leaves=100,colsample_bytree=0.01,subsample=0.91,max_depth=100)

# %%
B = model2.fit(X_train, y_train,eval_set=(X_validation, y_validation))
# Out:
# [1]	valid_0's l2: 1.9416
# [2]	valid_0's l2: 1.78816
# [3]	valid_0's l2: 1.76453
# [4]	valid_0's l2: 1.72294
# [5]	valid_0's l2: 1.58536
# [6]	valid_0's l2: 1.45983
# [7]	valid_0's l2: 1.35683
# [8]	valid_0's l2: 1.28989
# [9]	valid_0's l2: 1.26489
# [10]	valid_0's l2: 1.18831
# [11]	valid_0's l2: 1.05694
# [12]	valid_0's l2: 1.00756
# [13]	valid_0's l2: 1.00411
# [14]	valid_0's l2: 0.999091
# [15]	valid_0's l2: 0.974225
# [16]	valid_0's l2: 0.964059
# [17]	valid_0's l2: 0.959916
# [18]	valid_0's l2: 0.927073
# [19]	valid_0's l2: 0.838672
# [20]	valid_0's l2: 0.762123
# [21]	valid_0's l2: 0.748222
# [22]	valid_0's l2: 0.744721
# [23]	valid_0's l2: 0.725869
# [24]	valid_0's l2: 0.7225
# [25]	valid_0's l2: 0.721637
# [26]	valid_0's l2: 0.721077
# [27]	valid_0's l2: 0.675052
# [28]	valid_0's l2: 0.672953
# [29]	valid_0's l2: 0.671899
# [30]	valid_0's l2: 0.653161
# [31]	valid_0's l2: 0.652745
# [32]	valid_0's l2: 0.642286
# [33]	valid_0's l2: 0.62542
# [34]	valid_0's l2: 0.621365
# ...

# %%
city7 = train[train['city'] ==7]
city_7_0  = city7[city7['building_type'] != 4  ]

# %%
city_7_0

y = city_7_0['log_unit_price']
a = city_7_0['log_building_area']
x = city_7_0.iloc[:,1:-6]
x = pd.concat([x,a],axis=1)

# %%
x = x.fillna(0)

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X4,log_unit_y , train_size=0.7, random_state=1234)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
model=CatBoostRegressor(iterations=100, depth=8,l2_leaf_reg=0.01, learning_rate=0.1)
A = model.fit(X_train, y_train,eval_set=(X_validation, y_validation),plot=True)
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
# ...

# %%
A.score(X_validation,y_validation)
# Out:
# 0.8500003456251581

# %%
b = x.columns

# %%
from sklearn.decomposition import NMF

# %%
df_tmp = X2.iloc[:,32:]
df_tmp = df_tmp.iloc[:,:-1]

# %%
model3 = NMF(n_components=3)
w = model3.fit_transform(df_tmp)

# %%
X3 = pd.concat([X2,pd.DataFrame(w)],axis=1)

# %%
X3.shape
# Out:
# (60000, 237)

# %%
d = X3.iloc[:,-3:]
d.columns = ['NF_0','NF_1','NF_2']
X4 = pd.concat([X3,d],axis=1)
X4 = X4.drop([0,1,2],axis=1)

# %%
feature_score = pd.DataFrame(list(zip(x.dtypes.index, model.get_feature_importance(Pool(x, label=y)))),
                columns=['Feature','Score'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-206-3f984e34ae93> in <module>
# ----> 1 feature_score = pd.DataFrame(list(zip(X2.dtypes.index, model2.feature_importances_(Pool(X2, label=log_unit_y)))),
#       2                 columns=['Feature','Score'])
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
feature_imp = pd.DataFrame(sorted(zip(model2.feature_importances_,X4.columns)), columns=['Score','Feature'])

# %%
feature_imp[feature_imp['Feature'] == 'NF_2']
# Out:
#      Score Feature
# 227    279    NF_2

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x="Score", y="Feature", data=feature_imp)
sns.set(font_scale=0)
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.show()

# %%
f = feature_imp.sort_values(by="Score", ascending=False)

# %%
feature_score = feature_score.sort_values(by='Score', ascending=False, inplace=False, kind='quicksort', na_position='last')

# %%
c
# Out:
#                    Feature     Score
# 6     building_complete_dt  7.403366
# 2                   txn_dt  6.798584
# 10               txn_floor  5.842351
# 16   village_income_median  4.940019
# 17         town_population  4.357208
# 3              total_floor  4.292849
# 46                  I_5000  3.940997
# 172                 X_5000  2.806647
# 132              VII_10000  2.741388
# 14                     lat  2.515707
# 200               XII_5000  2.065595
# 18               town_area  1.808861
# 230              XIV_10000  1.674732
# 170                 X_1000  1.664111
# 130               VII_5000  1.647065

# %%
plt.subplots(figsize=(30, 20))
sns.barplot(x="Score", y="Feature",data=c)
sns.set(font_scale=1)

# %%
from vecstack import stacking

# %%
# Out:
#        building_material  city  txn_dt  total_floor  building_type  \
# 0                      8    21   18674            4              3
# 1                      8     7   18800            5              1
# 2                      8     7   19289            4              1
# 3                      8    21   20385           24              0
# 4                      1    21   20657            2              4
# 5                      8    21   18394            5              1
# 6                      8     7   20474           15              0
# 7                      8    12   18185            8              3
# 8                      8    21   18794            5              1
# 9                      8     7   19927           10              3
# 10                     1     7   18333            2              4
# 11                     8    21   18184            5              4
# 12                     8     7   18766            7              3
# ...

# %%
X_train, X_validation, y_train, y_validation = train_test_split(X4,log_unit_y , train_size=0.85, random_state=1206)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import r2_score

# %%
models = [
    XGBRegressor(n_estimators=200,reg:squarederror,n_jobs=-1),
        
    LGBMRegressor(n_estimators=200,learning_rate=0.1,num_leaves=100,colsample_bytree=0.01,subsample=0.91,max_depth=100),
        
    ExtraTreesRegressor(n_estimators=200,max_depth=40,n_jobs=-1),
    
    CatBoostRegressor(iterations=500, depth=8,l2_leaf_reg=0.01, learning_rate=0.1)
]

# %%
S_train, S_test = stacking(models,                   
                           X_train, y_train, X_validation,   
                           regression=True, 
     
                           mode='oof_pred_bag', 
       
                           needs_proba=False,
         
                           save_dir=None, 
            
                           metric=r2_score, 
    
                           n_folds=5, 
                 
                           stratified=True,
            
                           shuffle=True,  
            
                           random_state=1200,    
         
                           verbose=2)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\vecstack\core.py:459: UserWarning: This is regression task hence classification-specific parameters set to <True> were ignored: <stratified>
#   warnings.warn(warn_str, UserWarning)
# task:         [regression]
# metric:       [r2_score]
# mode:         [oof_pred_bag]
# n_models:     [4]
#
# model  0:     [XGBRegressor]
# [19:52:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#     fold  0:  [0.92512229]
# [19:52:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#     fold  1:  [0.92884724]
# [19:52:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#     fold  2:  [0.92637172]
# ...

# %%
model1 = XGBRegressor(n_estimators=200,max_depth=60,n_jobs=-1).fit(S_train,y_train)
model2 = LGBMRegressor(n_estimators=500,learning_rate=0.1,num_leaves=100,colsample_bytree=0.01,subsample=0.91,max_depth=100).fit(S_train,y_train)
model3 = CatBoostRegressor(iterations=100, depth=8,l2_leaf_reg=0.01, learning_rate=0.1).fit(S_train,y_train)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [20:35:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0:	learn: 17.5998796	total: 27.8ms	remaining: 2.75s
# 1:	learn: 15.8413960	total: 52.1ms	remaining: 2.55s
# 2:	learn: 14.2588397	total: 75.2ms	remaining: 2.43s
# 3:	learn: 12.8345518	total: 101ms	remaining: 2.42s
# 4:	learn: 11.5525855	total: 130ms	remaining: 2.47s
# 5:	learn: 10.3988340	total: 155ms	remaining: 2.43s
# 6:	learn: 9.3606615	total: 178ms	remaining: 2.36s
# 7:	learn: 8.4264478	total: 200ms	remaining: 2.3s
# 8:	learn: 7.5858643	total: 225ms	remaining: 2.28s
# 9:	learn: 6.8292854	total: 250ms	remaining: 2.25s
# 10:	learn: 6.1488241	total: 281ms	remaining: 2.27s
# 11:	learn: 5.5363539	total: 321ms	remaining: 2.35s
# ...

# %%
y_pred1 = model1.predict(S_test)
y_pred2 = model2.predict(S_test)
y_pred3 = model3.predict(S_test)

# %%
model3 = CatBoostRegressor(iterations=1000, depth=8,l2_leaf_reg=0.01, learning_rate=0.1).fit(S_train,y_train)
# Out:
# 0:	learn: 17.5998796	total: 25.1ms	remaining: 25.1s
# 1:	learn: 15.8413960	total: 47ms	remaining: 23.5s
# 2:	learn: 14.2588397	total: 70.4ms	remaining: 23.4s
# 3:	learn: 12.8345518	total: 91.9ms	remaining: 22.9s
# 4:	learn: 11.5525855	total: 117ms	remaining: 23.3s
# 5:	learn: 10.3988340	total: 140ms	remaining: 23.1s
# 6:	learn: 9.3606615	total: 163ms	remaining: 23.1s
# 7:	learn: 8.4264478	total: 188ms	remaining: 23.3s
# 8:	learn: 7.5858643	total: 210ms	remaining: 23.1s
# 9:	learn: 6.8292854	total: 234ms	remaining: 23.1s
# 10:	learn: 6.1488241	total: 259ms	remaining: 23.3s
# 11:	learn: 5.5363539	total: 285ms	remaining: 23.5s
# 12:	learn: 4.9854276	total: 308ms	remaining: 23.3s
# 13:	learn: 4.4897282	total: 331ms	remaining: 23.3s
# 14:	learn: 4.0441877	total: 353ms	remaining: 23.2s
# 15:	learn: 3.6431589	total: 377ms	remaining: 23.2s
# 16:	learn: 3.2828835	total: 401ms	remaining: 23.2s
# 17:	learn: 2.9587041	total: 424ms	remaining: 23.1s
# ...

# %%
y_train.shape
# Out:
# (51000,)

# %%
y_pred = (y_pred1+y_pred2+y_pred3)  / 3

# %%
print('Final prediction score: [%.8f]' % r2_score(y_validation, y_pred))
# Out:
# Final prediction score: [0.94496583]

# %%
print('Final prediction score: [%.8f]' % r2_score(y_validation, y_pred4))
# Out:
# Final prediction score: [0.94784608]

# %%
from sklearn.linear_model import LinearRegression

# %%
model4 = LinearRegression().fit(S_train,y_train)

# %%
y_pred4= model4.predict(S_test)
